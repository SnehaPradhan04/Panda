# %% [markdown]
# <a href="https://colab.research.google.com/github/SnehaPradhan04/Panda/blob/main/panda01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('california_housing_test.csv')
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['longitude',
#  'latitude',
#  'housing_median_age',
#  'total_rooms',
#  'total_bedrooms',
#  'population',
#  'households',
#  'median_income',
#  'median_house_value']

# %%
df.head(3)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0

# %%
df.tail(4)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
df['latitude']
# Out:
# 0       37.37
# 1       34.26
# 2       33.78
# 3       33.82
# 4       36.33
#         ...
# 2995    34.42
# 2996    34.06
# 2997    36.30
# 2998    34.10
# 2999    34.42
# Name: latitude, Length: 3000, dtype: float64

# %%
type(df['latitude'])
# Out:
# pandas.core.series.Series

# %%
list(df['latitude'])
# Out:
# [37.37,
#  34.26,
#  33.78,
#  33.82,
#  36.33,
#  36.51,
#  38.63,
#  35.48,
#  38.4,
#  34.08,
#  33.98,
#  35.85,
#  37.25,
#  32.97,
#  33.73,
#  33.81,
#  37.53,
#  38.69,
#  34.21,
#  38.01,
#  37.75,
#  38.68,
#  34.07,
#  37.79,
#  33.28,
#  34.16,
#  37.76,
#  33.99,
#  34.07,
#  34.01,
#  36.33,
#  33.91,
#  39.31,
#  34.55,
#  33.94,
#  34.0,
#  37.97,
#  33.92,
#  33.93,
#  34.23,
#  36.2,
#  32.77,
#  34.15,
#  34.09,
#  34.13,
#  33.17,
#  37.44,
#  33.94,
#  38.0,
#  33.78,
#  37.7,
#  35.97,
#  37.8,
#  33.8,
#  34.09,
#  33.93,
#  38.72,
#  34.26,
#  37.33,
#  37.25,
#  37.56,
#  37.23,
#  34.0,
#  40.87,
#  33.92,
#  32.73,
#  37.69,
#  33.92,
#  34.08,
#  33.86,
#  37.33,
#  34.04,
#  33.8,
#  37.36,
#  39.5,
#  37.49,
#  37.35,
#  34.2,
#  34.17,
#  37.99,
#  37.4,
#  34.05,
#  34.25,
#  38.26,
#  37.35,
#  37.68,
#  36.74,
#  34.08,
#  41.01,
#  37.62,
#  34.15,
#  37.98,
#  34.25,
#  33.87,
#  37.84,
#  36.64,
#  36.77,
#  38.42,
#  38.87,
#  33.77,
#  34.02,
# ...

# %%
df[['latitude']]
# Out:
#       latitude
# 0        37.37
# 1        34.26
# 2        33.78
# 3        33.82
# 4        36.33
# ...        ...
# 2995     34.42
# 2996     34.06
# 2997     36.30
# 2998     34.10
# 2999     34.42
#
# [3000 rows x 1 columns]

# %%
type(df[['latitude']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['total_bedrooms', 'population' ]]
# Out:
#       total_bedrooms  population
# 0              661.0      1537.0
# 1              310.0       809.0
# 2              507.0      1484.0
# 3               15.0        49.0
# 4              244.0       850.0
# ...              ...         ...
# 2995           642.0      1258.0
# 2996          1082.0      3496.0
# 2997           201.0       693.0
# 2998            14.0        46.0
# 2999           263.0       753.0
#
# [3000 rows x 2 columns]

# %%
df[['total_bedrooms', 'population', 'households', 'latitude', 'longitude']]
# Out:
#       total_bedrooms  population  households  latitude  longitude
# 0              661.0      1537.0       606.0     37.37    -122.05
# 1              310.0       809.0       277.0     34.26    -118.30
# 2              507.0      1484.0       495.0     33.78    -117.81
# 3               15.0        49.0        11.0     33.82    -118.36
# 4              244.0       850.0       237.0     36.33    -119.67
# ...              ...         ...         ...       ...        ...
# 2995           642.0      1258.0       607.0     34.42    -119.86
# 2996          1082.0      3496.0      1036.0     34.06    -118.14
# 2997           201.0       693.0       220.0     36.30    -119.70
# 2998            14.0        46.0        14.0     34.10    -117.12
# 2999           263.0       753.0       260.0     34.42    -119.63
#
# [3000 rows x 5 columns]

# %%
df1.head(4)
# Out:
#    Sl no.           Name   Roll no. Department
# 0       1  Sneha Pradhan  B210065EC        ECE
# 1       2   Smriti Verma  B210064EC        ECE
# 2       3  Saumya Ranjan  B210029CS        CSE
# 3       4     Akriti Jha  B210068EE        EEE

# %%
df1 = pd.read_excel("/detalis (2).xlsx")

# %%
df1.tail(2)
# Out:
#    Sl no.              Name   Roll no. Department
# 8       9   Avantash Ranjan  B210076EC        ECE
# 9      10  Vishwajeet Kumar  B210096EE        EEE

# %%
df1.dtypes
# Out:
# Sl no.         int64
# Name          object
# Roll no.      object
# Department    object
# dtype: object

# %%
df1.columns
# Out:
# Index(['Sl no.', 'Name', 'Roll no.', 'Department'], dtype='object')

# %%
df1['Name']
# Out:
# 0       Sneha Pradhan
# 1        Smriti Verma
# 2       Saumya Ranjan
# 3          Akriti Jha
# 4    Harsh Srivastava
# 5         Puru Jindal
# 6      Ashutosh Kumar
# 7      Tejas Khillare
# 8     Avantash Ranjan
# 9    Vishwajeet Kumar
# Name: Name, dtype: object

# %%
df1[['Name', 'Sl no.', 'Department']]
# Out:
#                Name  Sl no. Department
# 0     Sneha Pradhan       1        ECE
# 1      Smriti Verma       2        ECE
# 2     Saumya Ranjan       3        CSE
# 3        Akriti Jha       4        EEE
# 4  Harsh Srivastava       5        ECE
# 5       Puru Jindal       6        EEE
# 6    Ashutosh Kumar       7        ECE
# 7    Tejas Khillare       8        ECE
# 8   Avantash Ranjan       9        ECE
# 9  Vishwajeet Kumar      10        EEE
