# %% [markdown]
# <a href="https://colab.research.google.com/github/SnehaPradhan04/Panda/blob/main/Panda02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("Iris.csv")

# %%
df.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df[['Species']]
# Out:
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 1 columns]

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %%
df.dtypes == 'object'
# Out:
# Id               False
# SepalLengthCm    False
# SepalWidthCm     False
# PetalLengthCm    False
# PetalWidthCm     False
# Species           True
# dtype: bool

# %%
df.dtypes[df.dtypes == 'object']
# Out:
# Species    object
# dtype: object

# %%
df.dtypes[df.dtypes == 'object'].index
# Out:
# Index(['Species'], dtype='object')

# %%
df[df.dtypes[df.dtypes == 'object'].index]
# Out:
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 1 columns]

# %%
df[df.dtypes[df.dtypes == 'object'].index].describe()
# Out:
#             Species
# count           150
# unique            3
# top     Iris-setosa
# freq             50

# %%
df[df.dtypes[df.dtypes == 'int64'].index].describe()
# Out:
#                Id
# count  150.000000
# mean    75.500000
# std     43.445368
# min      1.000000
# 25%     38.250000
# 50%     75.500000
# 75%    112.750000
# max    150.000000

# %%
df[df.dtypes[df.dtypes == 'float64'].index].describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
df[['SepalLengthCm', 'SepalWidthCm']]
# Out:
#      SepalLengthCm  SepalWidthCm
# 0              5.1           3.5
# 1              4.9           3.0
# 2              4.7           3.2
# 3              4.6           3.1
# 4              5.0           3.6
# ..             ...           ...
# 145            6.7           3.0
# 146            6.3           2.5
# 147            6.5           3.0
# 148            6.2           3.4
# 149            5.9           3.0
#
# [150 rows x 2 columns]

# %%
df[['SepalLengthCm', 'SepalWidthCm']][4:12:2]
# Out:
#     SepalLengthCm  SepalWidthCm
# 4             5.0           3.6
# 6             4.6           3.4
# 8             4.4           2.9
# 10            5.4           3.7

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df['new_column'] = 0
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#    new_column
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
df['new_sum'] = df['SepalLengthCm'] + df['SepalWidthCm']
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#    new_column  new_sum
# 0           0      8.6
# 1           0      7.9
# 2           0      7.9
# 3           0      7.7
# 4           0      8.6

# %%
pd.Categorical(df['PetalLengthCm'])
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/lib/pretty.py:700: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   output = repr(obj)
# [1.4, 1.4, 1.3, 1.5, 1.4, ..., 5.2, 5.0, 5.2, 5.4, 5.1]
# Length: 150
# Categories (43, float64): [1.0, 1.1, 1.2, 1.3, ..., 6.4, 6.6, 6.7, 6.9]

# %%
pd.Categorical(df['Species'])
# Out:
# ['Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', ..., 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica']
# Length: 150
# Categories (3, object): ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df[df["SepalLengthCm"] > 5]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 10    11            5.4           3.7            1.5           0.2
# 14    15            5.8           4.0            1.2           0.2
# 15    16            5.7           4.4            1.5           0.4
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  new_column  new_sum
# 0       Iris-setosa           0      8.6
# 5       Iris-setosa           0      9.3
# ...

# %%
len(df) - len(df[df["SepalLengthCm"] > 5])
# Out:
# 32

# %%
df[df['PetalLengthCm'] < 3]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
df[df['PetalLengthCm'] > 3]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 50    51            7.0           3.2            4.7           1.4
# 51    52            6.4           3.2            4.5           1.5
# 52    53            6.9           3.1            4.9           1.5
# 53    54            5.5           2.3            4.0           1.3
# 54    55            6.5           2.8            4.6           1.5
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#              Species  new_column  new_sum
# 50   Iris-versicolor           0     10.2
# 51   Iris-versicolor           0      9.6
# ...

# %%
df[df['PetalLengthCm'] == 1.6]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 11  12            4.8           3.4            1.6           0.2  Iris-setosa
# 25  26            5.0           3.0            1.6           0.2  Iris-setosa
# 26  27            5.0           3.4            1.6           0.4  Iris-setosa
# 29  30            4.7           3.2            1.6           0.2  Iris-setosa
# 30  31            4.8           3.1            1.6           0.2  Iris-setosa
# 43  44            5.0           3.5            1.6           0.6  Iris-setosa
# 46  47            5.1           3.8            1.6           0.2  Iris-setosa
#
#     new_column  new_sum
# 11           0      8.2
# 25           0      8.0
# 26           0      8.4
# 29           0      7.9
# 30           0      7.9
# 43           0      8.5
# 46           0      8.9

# %%
df[df['PetalLengthCm'] == 1.6]['Species']
# Out:
# 11    Iris-setosa
# 25    Iris-setosa
# 26    Iris-setosa
# 29    Iris-setosa
# 30    Iris-setosa
# 43    Iris-setosa
# 46    Iris-setosa
# Name: Species, dtype: object

# %%
len(df[df['PetalLengthCm'] == 1.6])
# Out:
# 7

# %%
df[df['SepalLengthCm'] == 5.0]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 4    5            5.0           3.6            1.4           0.2
# 7    8            5.0           3.4            1.5           0.2
# 25  26            5.0           3.0            1.6           0.2
# 26  27            5.0           3.4            1.6           0.4
# 35  36            5.0           3.2            1.2           0.2
# 40  41            5.0           3.5            1.3           0.3
# 43  44            5.0           3.5            1.6           0.6
# 49  50            5.0           3.3            1.4           0.2
# 60  61            5.0           2.0            3.5           1.0
# 93  94            5.0           2.3            3.3           1.0
#
#             Species  new_column  new_sum
# 4       Iris-setosa           0      8.6
# 7       Iris-setosa           0      8.4
# 25      Iris-setosa           0      8.0
# 26      Iris-setosa           0      8.4
# 35      Iris-setosa           0      8.2
# ...
